# %% [markdown]
# # lrdata to MuData

# %% [markdown]
# ### Load packages

# %%
from pathlib import Path
import scanpy as sc
import liana as li

# %% [markdown]
# ### Convert lrdata to muData

# %%
lrdata_path  = Path("data/MERFISH_mouse_brain/")
adata = sc.read_h5ad(lrdata_path / "lrdata_C57BL6J_2.039.h5ad")

# %%
mdata = li.utils.anndata_to_mdata(
    adata = adata,
    groupby = "cell_type",
    by_var = False,
    verbose = True)
# Out:
# /home/alsayah/.local/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/alsayah/.local/lib/python3.10/site-packages/mudata/_core/mudata.py:963: UserWarning: Cannot join columns with the same name because var_names are intersecting.
# /home/alsayah/.local/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %% [markdown]
# ### Filter out modalities if ncells < 10 and/or ngenes <10

# %%
for mod_name, adata in mdata.mod.items():
    cells, genes = adata.shape  
    print(f"Modality: {mod_name}, Cells: {cells}, Genes: {genes}")
# Out:
# Modality: astrocyte, Cells: 6350, Genes: 782
# Modality: endothelial cell, Cells: 4113, Genes: 497
# Modality: macrophage, Cells: 146, Genes: 79
# Modality: vascular leptomeningeal cell, Cells: 989, Genes: 402
# Modality: glutamatergic neuron, Cells: 19633, Genes: 961
# Modality: oligodendrocyte precursor cell, Cells: 1443, Genes: 378
# Modality: GABAergic neuron, Cells: 5278, Genes: 807
# Modality: pericyte, Cells: 906, Genes: 225
# Modality: microglial cell, Cells: 1640, Genes: 283
# Modality: oligodendrocyte, Cells: 6461, Genes: 564
# Modality: smooth muscle cell, Cells: 343, Genes: 151
# Modality: lymphocyte, Cells: 45, Genes: 4
# Modality: dendritic cell, Cells: 13, Genes: 0
# Modality: neuroblast (sensu Vertebrata), Cells: 355, Genes: 202
# Modality: choroid plexus epithelial cell, Cells: 744, Genes: 287
# Modality: glycinergic neuron, Cells: 5, Genes: 0
# Modality: ependymal cell, Cells: 696, Genes: 333
# Modality: monocyte, Cells: 2, Genes: 0
# Modality: histaminergic neuron, Cells: 14, Genes: 12
# Modality: tanycyte, Cells: 182, Genes: 160
# Modality: dopaminergic neuron, Cells: 15, Genes: 9
# Modality: cholinergic neuron, Cells: 1, Genes: 0

# %%
filtered_mods = {key: adata for key, adata in mdata.mod.items() if adata.shape[0] >= 10 and adata.shape[1] >= 10}
mdata.mod = filtered_mods

# %%
for mod_name, adata in mdata.mod.items():
    cells, genes = adata.shape  
    print(f"Modality: {mod_name}, Cells: {cells}, Genes: {genes}")
# Out:
# Modality: astrocyte, Cells: 6350, Genes: 782
# Modality: endothelial cell, Cells: 4113, Genes: 497
# Modality: macrophage, Cells: 146, Genes: 79
# Modality: vascular leptomeningeal cell, Cells: 989, Genes: 402
# Modality: glutamatergic neuron, Cells: 19633, Genes: 961
# Modality: oligodendrocyte precursor cell, Cells: 1443, Genes: 378
# Modality: GABAergic neuron, Cells: 5278, Genes: 807
# Modality: pericyte, Cells: 906, Genes: 225
# Modality: microglial cell, Cells: 1640, Genes: 283
# Modality: oligodendrocyte, Cells: 6461, Genes: 564
# Modality: smooth muscle cell, Cells: 343, Genes: 151
# Modality: neuroblast (sensu Vertebrata), Cells: 355, Genes: 202
# Modality: choroid plexus epithelial cell, Cells: 744, Genes: 287
# Modality: ependymal cell, Cells: 696, Genes: 333
# Modality: histaminergic neuron, Cells: 14, Genes: 12
# Modality: tanycyte, Cells: 182, Genes: 160

# %% [markdown]
# ### Save mdata

# %%
mdata.write_h5mu(lrdata_path / "mdata_C57BL6J_2.039.h5mu")
# Out:
# ... storing 'lymphocyte:observation_joinid' as categorical
# ... storing 'dendritic cell:observation_joinid' as categorical
# ... storing 'glycinergic neuron:observation_joinid' as categorical
# ... storing 'monocyte:observation_joinid' as categorical
# ... storing 'dopaminergic neuron:observation_joinid' as categorical
# ... storing 'cholinergic neuron:observation_joinid' as categorical
# /home/alsayah/.local/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /home/alsayah/.local/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
